# %% [markdown]
# # 1. 파이썬 실행 환경과 기초 문법
#
# - 목표: 앞선 수업 내용을 전제로, 변수·자료형·연산자·조건문·반복문만 빠르게 복습합니다.
# - 흐름: 다음 차시에서 함수, 자료구조, 문자열, 파일 처리까지 한 번 더 정리합니다.

# %% [markdown]
# ## 1. 주피터 노트북 (Jupyter Notebook)
# - 웹 브라우저에서 실행되는 **대화형 개발 환경**
# - 코드(Cell)와 설명(Markdown)을 섞어 작성 가능
# - 데이터 분석, 시각화, 인공지능 실습에 최적화
# - 확장자: `.ipynb`
#
# 👉 **장점**
# - 코드 실행 결과를 즉시 확인 가능
# - 시각화 그래프, 수식, 이미지 삽입이 쉬움
# - 수업/연구 보고서 형태로 공유하기 적합
#
# 👉 **단점**
# - VS Code 등 전문 IDE에 비해 **코드 자동 완성, 디버깅, 프로젝트 관리 기능이 제한적임**
# - 대규모 프로젝트 개발보다는 **분석·실험용 노트북 환경**에 더 적합
#
# 설치 방법: Anaconda 배포판 설치 (파이썬, 주피터, 데이터 분석 라이브러리가 함께 설치됨)
# https://www.anaconda.com/download/success

# %% [markdown]
# ## 2. 구글 코랩 (Google Colab)
# - 구글에서 제공하는 **클라우드 기반 주피터 노트북 서비스**
# - 별도의 설치 필요 없음, 구글 계정만 있으면 바로 사용 가능
# - GPU/TPU 무료 지원 → 딥러닝 실습에 유리
#
# 👉 **장점**
# - 온라인 환경 → 어디서든 접속 가능
# - 무료 GPU 지원
# - 협업(공유, 댓글 기능) 용이
#
# 👉 **단점**
# - 인터넷 연결 필수
# - **실행 환경(세션)이 일정 시간이 지나면 초기화됨**
# - 무료 환경에서는 GPU 사용이 제한될 수 있음

# %% [markdown]
# ## 3. 비주얼 스튜디오 코드 (VS Code)
# - 마이크로소프트에서 제공하는 **범용 코드 에디터**
# - 확장 기능을 설치하면 **주피터 노트북 실행** 가능
# - 대규모 프로젝트 관리, 파이썬 외 다양한 언어 지원
# - 설치 : https://code.visualstudio.com/download
#
# 👉 **장점**
# - 가볍고 빠름
# - Git 연동, 디버깅 지원
# - 주피터와 함께 사용하면 노트북 + 스크립트 파일 모두 관리 가능
# - 인공지능 기반 코딩 보조 기능, 참조 등 매우 많은 기능을 지원

# %% [markdown]
# ## 4. 어떤 걸 선택할까?
# - **주피터 노트북** → 데이터 분석, 실습, 보고서 작성에 최적
# - **구글 코랩** → 설치 없이 GPU 사용 + 협업 환경
# - **VS Code** → 프로젝트 규모가 크고, 여러 언어/파일을 통합 관리할 때 유리
#
# 처음 문법을 익힐 때는 **주피터 노트북(.ipynb)** 으로 코드를 바로 실행하며 확인하는 방식이 가장 편합니다.
# 필요하면 코랩이나 VS Code로 같은 코드를 옮겨 실행할 수 있습니다.

# %% [markdown]
# # 파이썬 기초 문법

# %% [markdown]
# ## 1. 변수와 자료형
#
# ### 1) 변수란 무엇인가?
# - **변수(variable)** 는 **값(데이터)을 저장해두는 상자**와 같음
# - 컴퓨터가 기억해야 할 값을 이름을 붙여 보관하는 것
# - 한 번 저장해두면, 필요할 때 변수 이름을 불러서 재사용할 수 있음
#
# 예시:
# - 수학에서 `x = 5` 라고 하면, `x`라는 이름에 5라는 값이 들어있다고 이해
# - 프로그래밍에서도 같은 개념으로 `x`에 5를 넣고, 나중에 다시 꺼내 쓸 수 있음

# %% [markdown]
# ### 2) 파이썬 변수 사용법
# - 변수 이름 = 저장할 값
# - `=` 기호는 **같다(equal)** 가 아니라 **저장한다(assign)** 의 의미
#
# ```python
# x = 5       # 숫자 5를 x라는 변수에 저장
# y = 10      # 숫자 10을 y라는 변수에 저장
# name = "철수"  # 문자열 "철수"를 name이라는 변수에 저장
#
# print(x)       # 5 출력
# print(name)    # 철수 출력
# ```

# %% [markdown]
# ### 3) 파이썬의 자료형 (Data Type)
#
# 변수에는 다양한 형태의 데이터가 저장될 수 있음. 대표적인 자료형은 다음과 같음:
#
# - int : 정수형 (예: 10, -3)
# - float : 실수형, 소수점 포함 (예: 3.14, -2.5)
# - str : 문자열, 문자들의 집합 (예: "Hello", "Python")
# - bool : 불리언, 참(True) 또는 거짓(False)

# %% [markdown]
# ### 4) 자료형 변환 (Type Casting)
#
# 서로 다른 자료형을 변환할 수 있음.
#
# - int() : 정수형으로 변환
# - float() : 실수형으로 변환
# - str() : 문자열로 변환
# - bool() : 불리언으로 변환

# %%
# 변수 예시
a = 10        # 정수
b = 3.14      # 실수
c = "Hello"   # 문자열
d = True      # 불리언

print(a, b, c, d)  # 문자열을 정수로 바꿉니다.
print(type(a), type(b), type(c), type(d))  # 문자열을 정수로 바꿉니다.

# %%
x = "100"     # 문자열
y = int(x)    # 문자열을 정수로 변환
z = float(x)  # 문자열을 실수로 변환

print(x, type(x))  # "100" <class 'str'>
print(y, type(y))  # 100 <class 'int'>
print(z, type(z))  # 100.0 <class 'float'>

# %% [markdown]
# ## 2. 연산자
# - 산술 연산자: `+`, `-`, `*`, `/`, `//`, `%`, `**`
# - 비교 연산자: `==`, `!=`, `>`, `<`, `>=`, `<=`
# - 논리 연산자: `and`, `or`, `not`

# %%
x, y = 7, 3

print(x + y)   # 덧셈
print(x // y)  # 몫
print(x % y)   # 나머지
print(x ** y)  # 제곱

print(x > y)   # 비교
print(x == y)  # 문자열을 정수로 바꿉니다.

print((x > 5) and (y < 5))  # 논리 연산

# %% [markdown]
# ### ✍️ 복습 문제

# %% [markdown]
# ### 문제 1. 변수 할당
# 파이썬에서 변수 `x`에 숫자 10을 할당하고 출력하세요.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# x = 10  # 첫 번째 값 또는 배열을 준비합니다.
# print(x)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 여러 변수 동시 할당
#
# 파이썬에서 변수 a, b에 각각 5와 15를 동시에 할당하세요.
#
# <details> <summary>정답 보기</summary>
#
# a, b = 5, 15
# print(a, b)
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 변수 선언과 출력
# 아래 조건에 맞게 변수를 만들고 출력해보세요.
# - 정수 변수 `age`에 본인의 나이를 저장
# - 문자열 변수 `name`에 본인의 이름을 저장
# - 두 변수를 함께 출력하여 `"저는 OOO이고, 나이는 XX살입니다."` 형태로 나오도록 하세요.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# age = 25  # 나이 예제값입니다.
# name = "민수"  # 이름 예제값입니다.
# print(f"저는 {name}이고, 나이는 {age}살입니다.")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 자료형 확인
#
# 변수 s = "Python"의 자료형을 확인하세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# s = "Python"  # 문자열 인덱싱 예제값입니다.
# print(type(s))  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %% [markdown]
# ### 문제 5. 자료형 변환
#
# 변수 num = "123"을 정수형으로 변환하세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# num = "123"  # 정수로 바꿀 문자열입니다.
# num = int(num)  # 문자열을 정수로 바꿉니다.
# print(num, type(num))  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
num = 123

# %% [markdown]
# ### 문제 6. 연산자 연습
# 정수 변수 `a = 15`, `b = 4`를 선언한 후, 아래 결과를 출력하세요.
# 1. a를 b로 나눈 **몫**
# 2. a를 b로 나눈 **나머지**
# 3. a가 b보다 큰지 비교한 결과 (True/False)
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# a = 15  # 조건문 확인용 숫자입니다.
# b = 4  # 모델이 학습할 절편입니다.
#
# print(a // b)  # 결과를 화면에 출력합니다.
# print(a % b)  # 결과를 화면에 출력합니다.
# print(a > b)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 7. 비교 연산자
#
# 변수 x = 10, y = 20일 때, x < y와 x == y의 결과를 출력하세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# x, y = 10, 20  # 첫 번째 값 또는 배열을 준비합니다.
# print(x < y)  # 결과를 화면에 출력합니다.
# print(x == y)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %% [markdown]
# ### 문제 8. 논리 연산자 활용
#
# 변수 `x = 10`, `y = 20`일 때, 아래 식의 결과를 구해보세요.
#
# 1. (x > 5) and (y > 15)
# 2. (x < 5) or (y == 20)
# 3. not(x == 10)
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# x = 10  # 첫 번째 값 또는 배열을 준비합니다.
# y = 20  # 정답 값 또는 두 번째 배열을 준비합니다.
#
# print((x > 5) and (y > 15))  # 결과를 화면에 출력합니다.
# print((x < 5) or (y == 20))  # 결과를 화면에 출력합니다.
# print(not (x == 10))  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 9. 문자열 연산
#
# 문자열 "Hello"와 "World"를 공백 하나를 두고 이어붙이세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 문자열을 다루기 쉬운 형태로 정리합니다.
# # 필요한 값만 추출하거나 비교합니다.
#
# s1 = "Hello"  # 결합할 첫 번째 문자열입니다.
# s2 = "World"  # 결합할 두 번째 문자열입니다.
# result = s1 + " " + s2  # 두 문자열을 공백과 함께 합칩니다.
# print(result)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %% [markdown]
# ## 3. 조건문 (if 문)
# ### 1) 조건문이란?
# - 프로그램이 **상황에 따라 다른 행동**을 하도록 만드는 문장.
# - 어떤 **조건식**이 참(True)이면 특정 코드를 실행하고, 거짓(False)이면 건너뜁니다.
#
# ### 2) 기본 문법(형식)
#
# ```python
# if 조건식:
#     # 조건식이 True일 때 실행되는 코드 블록
# elif 다른_조건식:
#     # 위 if가 False이고, 이 조건이 True일 때 실행
# else:
#     # 위 모든 조건이 False일 때 실행
# ```
#
# - : (콜론)을 잊지 말 것.
# - 들여쓰기(Indentation): 블록은 보통 공백 4칸으로 들여쓰기. 탭/스페이스 혼용 금지.
# - if, elif, else는 필요한 만큼 쓸 수 있지만, else는 0개 또는 1개만 사용합니다.

# %% [markdown]
# ### 핵심 정리
# - 기본 구조: `if` → (필요 시) `elif` → (선택) `else`
# - `:`(콜론)과 **들여쓰기(공백 4칸)** 필수
# - 간단한 분기는 **조건부 표현식**으로 한 줄에 가능: `A if 조건 else B`
# - 자주 하는 실수: `=`(대입) vs `==`(비교), 콜론 누락, 들여쓰기 오류

# %%
score = 85

if score >= 90:
    print("A 학점")  # 문자열을 정수로 바꿉니다.
elif score >= 80:
    print("B 학점")  # 문자열을 정수로 바꿉니다.
else:
    print("C 학점 이하")  # 문자열을 정수로 바꿉니다.

# %% [markdown]
# ### 조건문 복습 문제
#
# ### 문제 1. 배수 판별 (단일 if)
# 정수 `n`이 주어졌을 때,
# - `n`이 3의 배수면 `"3의 배수입니다"`
# - `n`이 5의 배수면 `"5의 배수입니다"`
# 를 각각 출력하세요.
# (단, 공배수는 고려하지 않고, 해당하는 조건만 따로 출력)
#
# 예시)
# - n = 9 → "3의 배수입니다"
# - n = 10 → "5의 배수입니다"

# %%
# 여기에 코드를 작성하세요
n = int(input())  # 문자열을 정수로 바꿉니다.

# %% [markdown]
# ### 문제 2. 배수 판별 (공배수 고려, 중첩 if)
# 정수 `n`이 주어졌을 때,
# - `n`이 3과 5의 **공배수**라면 `"3과 5의 공배수입니다"`
# - 그렇지 않고 3의 배수라면 `"3의 배수입니다"`
# - 그렇지 않고 5의 배수라면 `"5의 배수입니다"`
# 를 출력하세요.
#
# 힌트: `if` 안에 `if`를 넣어 중첩 조건문을 사용해보세요.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# n = 15  # 조건 확인에 사용할 숫자입니다.
#
# if n % 3 == 0:  # 조건을 확인합니다.
#     if n % 5 == 0:  # 조건을 확인합니다.
#         print("3과 5의 공배수입니다")  # 결과를 화면에 출력합니다.
#     else:  # 위 조건에 모두 해당하지 않을 때 실행합니다.
#         print("3의 배수입니다")  # 결과를 화면에 출력합니다.
# elif n % 5 == 0:  # 앞 조건이 아니면 다음 조건을 확인합니다.
#     print("5의 배수입니다")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
n = int(input())  # 문자열을 정수로 바꿉니다.

# %% [markdown]
# ### 문제 3. 응용: 점수 등급 판별
#
# 점수 `score`가 주어졌을 때, 다음 기준으로 학점을 출력하세요.
# - 90점 이상: "A 학점"
# - 80점 이상: "B 학점"
# - 70점 이상: "C 학점"
# - 그 외: "D 학점 이하"
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# score = 85  # 등급 판단에 사용할 점수입니다.
#
# if score >= 90:  # 조건을 확인합니다.
#     print("A 학점")  # 결과를 화면에 출력합니다.
# elif score >= 80:  # 앞 조건이 아니면 다음 조건을 확인합니다.
#     print("B 학점")  # 결과를 화면에 출력합니다.
# elif score >= 70:  # 앞 조건이 아니면 다음 조건을 확인합니다.
#     print("C 학점")  # 결과를 화면에 출력합니다.
# else:  # 위 조건에 모두 해당하지 않을 때 실행합니다.
#     print("D 학점 이하")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
score = int(input())  # 문자열을 정수로 바꿉니다.

# %% [markdown]
# ### 한 줄 if문 (조건부 표현식)
#
# 파이썬에서는 조건문을 간단하게 한 줄로 표현할 수 있습니다.
# 형식은 다음과 같습니다:
#
# ```python
# 값_if_참일때 if 조건 else 값_if_거짓일때
# ```
#
# 즉, 조건이 참(True) 이면 앞의 값을, 거짓(False) 이면 뒤의 값을 반환합니다.
# 일반적인 if-else 문을 짧게 줄여 쓸 때 유용합니다.
#
# 예시 :
# ```python
# a = 2
# print(True if a>3 else False) # 출력 : False
# ```

# %% [markdown]
# ### 문제 4. 한 줄 if문 기본
#
# 변수 x = 7일 때, x가 10 이상이면 "크다", 아니면 "작다"를 출력하는 한 줄 if문을 작성하세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# x = 7  # 첫 번째 값 또는 배열을 준비합니다.
# print("크다" if x >= 10 else "작다")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
x = 7

# %% [markdown]
# ### 문제 5. 홀짝 판별
#
# 변수 n = 13일 때, n이 짝수면 "Even", 홀수면 "Odd"를 출력하는 한 줄 if문을 작성하세요.
#
# <details> <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# n = 13  # 판별할 숫자입니다.
# print("Even" if n % 2 == 0 else "Odd")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
n = 13

# %% [markdown]
# ## 4. 반복문
# ### 1) 반복문이란?
# - 프로그램에서 **같은 동작을 여러 번 반복**하고 싶을 때 사용.
# - 일일이 코드를 여러 줄 작성하지 않고, 반복문을 이용하면 짧고 효율적으로 작성 가능.
#
# 예시:
# - "안녕하세요"를 5번 출력하기
# - 1부터 10까지 숫자 합 구하기
# - 리스트 안의 모든 원소를 하나씩 처리하기
#
#
# #### for 문
# - **정해진 횟수**만큼 반복할 때 사용.
# - `range()` 함수와 함께 자주 사용.
#
# #### 기본 문법
# ```python
# for 변수 in 반복할_대상:
#     실행할 코드
# ```
#
# - 반복할_대상에는 리스트, 문자열, range() 등이 올 수 있음.
# - 매 반복마다 변수가 순서대로 바뀌며 실행됨.

# %%
# 1부터 5까지 출력
for i in range(1, 6):   # 1 이상 6 미만
    print(i)  # 문자열을 정수로 바꿉니다.

# 리스트 순회
fruits = ["apple", "banana", "cherry"]
for f in fruits:
    print(f)  # 문자열을 정수로 바꿉니다.

# %% [markdown]
# #### 3) while 문
#
# 조건식이 True인 동안 계속 반복.
#
# 조건이 False가 되면 반복 종료.
#
# ```python
# while 조건식:
#     실행할 코드
# ```
#
# **조건을 잘못 주면 무한 루프에 빠질 수 있으니 주의.**
#
# #### 예시
# ```python
# n = 1
# while n <= 5:
#     print("카운트:", n)  # 문자열을 정수로 바꿉니다.
#     n += 1   # n이 계속 커져야 반복이 끝남
# ```

# %% [markdown]
# ### 4) 반복 제어 키워드
#
# break : 반복문을 즉시 종료
#
# continue : 이번 반복만 건너뛰고 다음 반복으로 진행
#
# ```python
# # break 예시
# for i in range(1, 10):
#     if i == 5:
#         break
#     print(i)   # 1, 2, 3, 4만 출력
#
# # continue 예시
# for i in range(1, 6):
#     if i == 3:
#         continue
#     print(i)   # 1, 2, 4, 5 출력
# ```

# %% [markdown]
# #### 5) 참고 : for vs while 선택 기준
#
# **반복 횟수가 명확히 정해진 경우 → for**
# **조건에 따라 반복을 계속해야 하는 경우 → while**
#
# -> 반드시 위 내용대로 정할 필요는 없음

# %% [markdown]
# #### 6) 자주 하는 실수
#
# while에서 증가식/종료 조건을 빼먹어 무한 루프 발생
#
# range(1, 6)은 1~6까지가 아니라 1 이상 6 미만
#
# for문에서 들여쓰기 실수 → 반복 안 되거나 에러 발생

# %% [markdown]
# ### 반복문 복습 문제
#
# ### 문제 1. 구구단 출력 (for 문)
# 정수 `n`을 입력받아, 해당 구구단을 출력하세요.
# 예시) n = 3
# 3 x 1 = 3
# 3 x 2 = 6
# ...
# 3 x 9 = 27

# %%
# 여기에 코드를 작성하세요
n = 3

# %% [markdown]
# ### 문제 2. 짝수의 합 구하기 (while 문)
# 1부터 100까지의 정수 중에서 **짝수의 합**을 while 문으로 구하세요.
# 출력 예시) `1부터 100까지 짝수의 합은 2550입니다.`
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# total = 0  # 누적 합계를 0에서 시작합니다.
# n = 2  # 더할 첫 짝수입니다.
#
# while n <= 100:  # 조건이 참인 동안 반복합니다.
#     total += n  # 현재 숫자를 합계에 더합니다.
#     n += 2  # 다음 짝수로 이동합니다.
#
# print(f"1부터 100까지 짝수의 합은 {total}입니다.")  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %% [markdown]
# ### 문제 3. break와 continue 연습
# 1부터 10까지 숫자를 출력하는데,
# - 5에서 멈추도록(`break`) 하세요.
# - 단, 3은 건너뛰고(`continue`) 출력하지 않도록 하세요.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# for i in range(1, 11):  # 값을 하나씩 꺼내 반복합니다.
#     if i == 3:  # 조건을 확인합니다.
#         continue  # 이번 반복을 건너뛰고 다음 반복으로 갑니다.
#     if i == 5:  # 조건을 확인합니다.
#         break  # 반복문을 종료합니다.
#     print(i)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 코드를 작성하세요
n = 3

# %% [markdown]
# ## 선택(심화) 문제
#
# 기본 문제를 마친 뒤 선택해서 풉니다.
# 막히는 문제는 표시해두고 다음 개념으로 넘어가도 괜찮습니다.

# %% [markdown]
# ### 선택(심화) 1. 1부터 100까지 소수만 출력하기
#
# `for`문과 `if`문을 이용해 1부터 100까지의 소수만 출력해 보세요.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# primes = []  # 찾은 소수를 담을 리스트입니다.
#
# for num in range(2, 101):  # 값을 하나씩 꺼내 반복합니다.
#     is_prime = True  # 소수라고 가정하고 검사를 시작합니다.
#
#     for div in range(2, num):  # 값을 하나씩 꺼내 반복합니다.
#         if num % div == 0:  # 조건을 확인합니다.
#             is_prime = False  # 나누어떨어지면 소수가 아닙니다.
#             break  # 반복문을 종료합니다.
#
#     if is_prime:  # 조건을 확인합니다.
#         primes.append(num)
#
# print(primes)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 작성하세요

# %% [markdown]
# ### 선택(심화) 2. 정수의 각 자리수 합 구하기
#
# 예를 들어 `47253`이 주어졌을 때 `4 + 7 + 2 + 5 + 3`의 결과를 구해 보세요.
# 문자열로 바꾸지 않고 `while`문으로 풀어봐도 좋습니다.
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# n = 47253  # 자릿수 합을 구할 숫자입니다.
# total = 0  # 누적 합계를 0에서 시작합니다.
#
# while n > 0:  # 조건이 참인 동안 반복합니다.
#     total += n % 10  # 마지막 자릿수를 합계에 더합니다.
#     n //= 10  # 마지막 자릿수를 제거합니다.
#
# print(total)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 작성하세요

# %% [markdown]
# ### 선택(심화) 3. 가운데 정렬 피라미드 출력하기
#
# 높이 `5`의 피라미드를 아래처럼 출력해 보세요.
#
# ```text
#     *
#    ***
#   *****
#  *******
# *********
# ```
#
# <details>
# <summary>정답 보기</summary>
#
# ```python
# # 풀이 흐름: 필요한 값을 만들고 결과를 확인합니다.
# # 문제에서 요구한 결과를 계산하고 확인합니다.
#
# height = 5  # 별 피라미드의 높이입니다.
#
# for i in range(1, height + 1):  # 값을 하나씩 꺼내 반복합니다.
#     spaces = " " * (height - i)  # 왼쪽 여백을 만듭니다.
#     stars = "*" * (2 * i - 1)  # 현재 줄의 별 개수입니다.
#     print(spaces + stars)  # 결과를 화면에 출력합니다.
#
# ```
# </details>

# %%
# 여기에 작성하세요
